# %% [markdown]
# # The Key Terms for Friday
#
# * top-down design

# %% [markdown]
# # Top-Down Design
#
# Remember early in the semester when I said algorithmic thinking is at the core of computer science? A computer scientist has three types of thing in their skills kit:
#
# 1. A set of tools for solving problems (like lego pieces). These tools are **data structures** (like lists, dictionaries and trees!) and **algorithms** (like iteration, sort and search!).
# 2. One or more ways to write those tools down (a natural language like English, pseudocode, python, Java....)
# 3. A structured process for defining a big problem and breaking it down into smaller problems that can be solved using the tools they know. This is typically done using **top-down design**.
#
# **Top-down design** is "a method of breaking a problem down into smaller, less complex pieces from the initial overall problem" (from https://computer-based-problem-solving.readthedocs.io/en/latest/problem-solving/top-down-design.html).

# %% [markdown]
# ## How a Computer Scientist Solves Problems
#
#
# | | Generic Step | Computer Programming Step | Comment |
# | - | ---------- | ------------------------- | ------- |
# | #1 | What is the problem | Top-Down Chart | In software engineering, this can be called requirements specification. You have to really understand the nature of the problem. |
# | #2 | Make a model | Flow Chart | Check the model with the users or customer before proceeding! |
# | #3 | Analyze the model | Pseudocode | Write down solutions to each box in the flow chart in "English-like". |
# | #4 | Find the solution | Actually type in the code | Make sure it is pythonic and efficient! |
# | #5 | Check the solution | Style check & test for errors | Get some sample inputs from your user or customer in #1. |
# | #6 | Document the solution | Document the code – comments & GitHub | Tie each part of the solution back to the model and problem statement! |
#
# Problem-solving for computer scientists, from https://computer-based-problem-solving.readthedocs.io/en/latest/problem-solving/computer-problem-solving.html

# %% [markdown]
# ## What is the problem? (NLP example)
#
# Let's make a top-down design for "inspect a corpus". Some steps might be:
#
# * Load (or read) the corpus
# * Look at one document in the corpus
# * Get the size of the corpus
# * Process the corpus using NLP
# * Make a word cloud for the corpus
#
# This is our time to list all the steps and structure them.

# %% [markdown]
# ## Make a model (NLP example)
#
# Now let's convert our top-down design to a flow chart.
#
# ![image.png](attachment:image.png)
#
# Image source: https://computer-based-problem-solving.readthedocs.io/en/latest/problem-solving/flow-charts.html

# %% [markdown]
# ## Analyze the model (NLP example)
#
# Now write out the solution to at least one of the boxes in the flow chart in pseudocode.
#
# Which of the boxes we made corresponds to a function in `spacy_on_corpus.py`?
